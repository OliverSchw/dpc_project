# %%
import jax
import jax.nn as jnn
import jax.numpy as jnp
import numpy as np

import equinox as eqx
import optax
import matplotlib.pyplot as plt
from exciting_environments.pmsm.pmsm_env import PMSM
# Out:
# 2025-04-02 13:09:00.226325: W external/xla/xla/service/gpu/nvptx_compiler.cc:760] The NVIDIA driver's CUDA version is 12.2 which is older than the ptxas CUDA version (12.6.77). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.

# %%
import os
os.chdir("..")
from policy.policy_training import DPCTrainer
from models.models import NeuralEulerODE,MLP

# %%
gpus = jax.devices()
jax.config.update("jax_default_device", gpus[1])

# %%
motor_env = PMSM(
    saturated=True,
    LUT_motor_name="BRUSA",
    batch_size=1,
    control_state=[], 
    static_params = {
            "p": 3,
            "r_s": 15e-3,
            "l_d": 0.37e-3,
            "l_q": 1.2e-3,
            "psi_p": 65.6e-3,
            "deadtime": 0,
    })

# %% [markdown]
# Reset function to get random initial_observation for training of the dpc - using pmsm_env reset for random init:

# %%
@eqx.filter_jit
def reset(node,rng):
    obs, _ = motor_env.reset(motor_env.env_properties, rng) 
    #obs = obs.at[2].set((3*1500 / 60 * 2 * jnp.pi) / (2 * jnp.pi * 3 * 11000 / 60))
    return obs

# %% [markdown]
# Function returns random initial_observation and reference_observation the dpc should target while training:

# %%
@eqx.filter_jit
def dat_gen_sin(node, rng, traj_len):
    rng, subkey = jax.random.split(rng)
    ref_obs = reset(node,subkey) 
    rng, subkey = jax.random.split(rng)
    init_obs = reset(node,subkey)  
    return init_obs, ref_obs, rng

# %% [markdown]
# Featurize function for the dpc policy - feat_obs is input of the dpc_policy network:

# %%
@eqx.filter_jit
def featurize(obs,ref_obs, featurize_state=jnp.array([0,0])):
    feat_obs=jnp.concatenate([obs[0:2],ref_obs[0:2],ref_obs[0:2]-obs[0:2],featurize_state])
    featurize_state=jnp.clip(featurize_state + ref_obs[0:2]-obs[0:2],min=-1,max=1) * (jnp.sign(0.01-jnp.sum((ref_obs[0:2]-obs[0:2])**2))*0.5+0.5)
    return feat_obs,featurize_state

# %% [markdown]
# Loss for reference tracking:

# %%
@eqx.filter_jit
def mse_loss(feat_obs):
    loss=jnp.mean(jnp.sum((feat_obs[:,4:6])**2,axis=1))#be aware of idx if changing featurize
    return loss

# %% [markdown]
# Soft constraints:

# %%
@eqx.filter_jit
def penalty_loss(feat_obs):
    i_d=feat_obs[:,0]*0.5-0.5
    i_q=feat_obs[:,1]
    penalties = jnp.sum(jax.nn.relu(i_d**2+i_q**2-1))
    return penalties

# %% [markdown]
# Initialize dpc-policy:

# %%
jax_key = jax.random.PRNGKey(2)
policy=MLP([8,64,64,64,2],key=jax_key)
optimizer = optax.adam(5e-4)
opt_state = optimizer.init(policy)

# %% [markdown]
# Design training structure:

# %%
data_batch_size=100
pre_trainer=DPCTrainer(
    batch_size=data_batch_size,
    train_steps=2500,
    horizon_length=5,
    data_gen_sin=dat_gen_sin,
    featurize=featurize,
    policy_optimizer=optimizer,
    ref_loss=mse_loss,
    constr_penalty=penalty_loss,
    ref_loss_weight=1)
keys=jax.vmap(jax.random.PRNGKey)(np.random.randint(0, 2**31, size=(data_batch_size,)))
#key=jax.vmap(jax.random.PRNGKey)(jnp.linspace(0,1000,1001).astype(int))

# %%
pre_policy_env,pre_opt_state2,pre_keys2,losses2, val_losses=pre_trainer.fit_on_env(policy,motor_env,keys,opt_state)
plt.plot(losses2)
plt.yscale('log')
# Out:
# 100%|██████████| 2500/2500 [00:34<00:00, 71.47it/s]

# %%
data_batch_size=100
trainer=DPCTrainer(
    batch_size=data_batch_size,
    train_steps=2500,
    horizon_length=20,
    data_gen_sin=dat_gen_sin,
    featurize=featurize,
    policy_optimizer=optimizer,
    ref_loss=mse_loss,
    constr_penalty=penalty_loss,
    ref_loss_weight=1)
keys=jax.vmap(jax.random.PRNGKey)(np.random.randint(0, 2**31, size=(data_batch_size,)))
#key=jax.vmap(jax.random.PRNGKey)(jnp.linspace(0,1000,1001).astype(int))

# %% [markdown]
# ### 2.Example: DPC Training on pmsm_env

# %%
fin_policy_env,fin_opt_state2,fin_keys2,losses2, val_losses=trainer.fit_on_env(pre_policy_env,motor_env,keys,opt_state)
plt.plot(losses2)
plt.yscale('log')
# Out:
# 100%|██████████| 2500/2500 [01:02<00:00, 39.79it/s]

# %% [markdown]
# ## Evaluate on pmsm_env (motor_env):

# %%
from utils.evaluation import steps_eval

# %%
obs,obs_ref,acts=steps_eval(motor_env,reset,fin_policy_env,featurize,jax.random.PRNGKey(2),2000)

# %%
motor_env_lin = PMSM(
    saturated=False,
    LUT_motor_name="BRUSA",
    batch_size=1,
    control_state=[], 
    static_params = {
            "p": 3,
            "r_s": 15e-3,
            "l_d": 0.37e-3,
            "l_q": 1.2e-3,
            "psi_p": 65.6e-3,
            "deadtime": 0,
    })

# %%
pre_policy_env_lin,pre_opt_state2,pre_keys2,losses2, val_losses=pre_trainer.fit_on_env(policy,motor_env_lin,keys,opt_state)
plt.plot(losses2)
plt.yscale('log')
# Out:
# 100%|██████████| 2500/2500 [00:15<00:00, 162.32it/s]

# %%
fin_policy_env_lin,fin_opt_state2,fin_keys2,losses2, val_losses=trainer.fit_on_env(pre_policy_env_lin,motor_env_lin,keys,opt_state)
plt.plot(losses2)
plt.yscale('log')
# Out:
# 100%|██████████| 2500/2500 [00:17<00:00, 140.04it/s]

# %%
obs,obs_ref,acts=steps_eval(motor_env_lin,reset,fin_policy_env_lin,featurize,jax.random.PRNGKey(2),2000)
