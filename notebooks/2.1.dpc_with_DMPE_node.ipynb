# %%
import jax
import jax.nn as jnn
import jax.numpy as jnp
import numpy as np

import equinox as eqx
import diffrax
import optax
import matplotlib.pyplot as plt

# %%
import os
os.chdir("..")
from policy.policy_training import DPCTrainer
from exciting_environments.pmsm.pmsm_env import PMSM
from policy.networks import MLP#,MLP2
from utils.interactions import rollout_traj_env_policy
from models.model_training import ModelTrainer
from models.models import NeuralEulerODE
# Out:
# 2024-12-04 10:46:53.116316: W external/xla/xla/service/gpu/nvptx_compiler.cc:760] The NVIDIA driver's CUDA version is 12.2 which is older than the ptxas CUDA version (12.6.77). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.

# %%
class NodeInEnvWrapper:
    def __init__(self,node,motor_env):
        self.motor_env=motor_env
        self.node=node
        self.env_properties= motor_env.env_properties
    
    def step(self,state, action,env_properties):
        obs=self.motor_env.generate_observation(state,self.motor_env.env_properties)
        obs2= self.node.step(obs[0:2], action, self.motor_env.tau)
        obs = obs.at[0].set(obs2[0])
        obs = obs.at[1].set(obs2[1])
        state= self.motor_env.generate_state_from_observation(obs,self.motor_env.env_properties)
        return obs ,state
    
    def generate_state_from_observation(self, init_obs, env_properties):
        return self.motor_env.generate_state_from_observation(init_obs,self.motor_env.env_properties)

# %%
class EnvInNodeWrapper:
    def __init__(self,motor_env):
        self.motor_env=motor_env
    
    def step(self, obs ,action,tau):
        obs1,_= self.motor_env.reset(self.motor_env.env_properties)  #
        obs1 = obs1.at[2].set((3*1500 / 60 * 2 * jnp.pi) / (2 * jnp.pi * 3 * 11000 / 60))
        obs1 = obs1.at[0].set(obs[0])
        obs1 = obs1.at[1].set(obs[1])
        state=self.motor_env.generate_state_from_observation(obs1,self.motor_env.env_properties)
        obs,_= self.motor_env.step(state, action, self.motor_env.env_properties)
        return obs[0:2]

# %%
gpus = jax.devices()
jax.config.update("jax_default_device", gpus[0])

# %%
motor_env = PMSM(
    saturated=True,
    LUT_motor_name="BRUSA",
    batch_size=1,
    control_state=[], 
    static_params = {
            "p": 3,
            "r_s": 15e-3,
            "l_d": 0.37e-3,
            "l_q": 1.2e-3,
            "psi_p": 65.6e-3,
            "deadtime": 0,
    })

# %%
@eqx.filter_jit
def reset(node,rng):
    obs, _ = motor_env.reset(motor_env.env_properties, rng)  #
    obs = obs.at[2].set((3*1500 / 60 * 2 * jnp.pi) / (2 * jnp.pi * 3 * 11000 / 60))
    return obs

# %%
@eqx.filter_jit
def node_dat_gen_sin(node,reset_env, rng, traj_len):
    rng, subkey = jax.random.split(rng)
    ref_obs = reset_env(node,subkey) 
    rng, subkey = jax.random.split(rng)
    init_obs = reset_env(node,subkey)  
    return init_obs, ref_obs, rng

# %%
@eqx.filter_jit
def featurize(obs,ref_obs, featurize_state=jnp.array([0,0])):
    feat_obs=jnp.concatenate([obs[0:2],ref_obs[0:2],ref_obs[0:2]-obs[0:2],featurize_state])#jnp.concatenate([obs[0:2],obs[6:8],ref_obs[0:2],ref_obs[0:2]-obs[0:2],featurize_state])
    #featurize_state=jnp.clip(featurize_state + ref_obs[0:2]-obs[0:2],min=-1,max=1) * (jnp.sign(0.01-jnp.sum((ref_obs[0:2]-obs[0:2])**2))*0.5+0.5)
    return feat_obs,featurize_state

# %%
@eqx.filter_jit
def mse_loss(feat_obs):
    loss=jnp.mean(jnp.sum((feat_obs[:,4:6])**2,axis=1))#be aware of idx if changing featurize
    return loss

# %%
@eqx.filter_jit
def penalty_loss(feat_obs):
    loss=jnp.array([0])
    return loss

# %%
jax_key = jax.random.PRNGKey(2)
policy=MLP([8,64,64,64,2],key=jax_key)
optimizer = optax.adam(5e-4)
opt_state = optimizer.init(policy)

# %%
data_batch_size=100
trainer=DPCTrainer(
    batch_size=data_batch_size,
    train_steps=5000,
    horizon_length=25,
    reset_env=reset,
    data_gen_sin=node_dat_gen_sin,
    featurize=featurize,
    policy_optimizer=optimizer,
    ref_loss=mse_loss,
    constr_penalty=penalty_loss,
    ref_loss_weight=1)
keys=jax.vmap(jax.random.PRNGKey)(np.random.randint(0, 2**31, size=(data_batch_size,)))
#key=jax.vmap(jax.random.PRNGKey)(jnp.linspace(0,1000,1001).astype(int))

# %%
def featurize_node(obs):
    return obs[:2]

# %%
jax_key = jax.random.PRNGKey(2)
node_struct=NeuralEulerODE([4,128,128,128,128,2],key=jax_key)
node = eqx.tree_deserialise_leaves("trained_models/DMPE_Model_100k_100len_100b_step0_0001.eqx", node_struct)

# %%
fin_policy_100,fin_opt_state,fin_keys,losses=trainer.fit_on_node_non_jit(policy, node, motor_env.tau, featurize_node, keys, opt_state)
plt.plot(losses)
plt.yscale('log')
# Out:
# 100%|██████████| 5000/5000 [00:51<00:00, 96.17it/s]

# %%
jax_key = jax.random.PRNGKey(2)
node_struct=NeuralEulerODE([4,128,128,128,128,2],key=jax_key)
node = eqx.tree_deserialise_leaves("trained_models/DMPE_Model_100k_50len_100b_step0_0001.eqx", node_struct)

# %%
fin_policy_50,fin_opt_state,fin_keys,losses=trainer.fit_on_node_non_jit(policy, node, motor_env.tau, featurize_node, keys, opt_state)
plt.plot(losses)
plt.yscale('log')
# Out:
# 100%|██████████| 5000/5000 [00:44<00:00, 112.43it/s]

# %%
jax_key = jax.random.PRNGKey(2)
node_struct=NeuralEulerODE([4,128,128,128,128,2],key=jax_key)
node = eqx.tree_deserialise_leaves("trained_models/DMPE_Model_200k_1len_100b_step0_0001.eqx", node_struct)

# %%
fin_policy_1,fin_opt_state,fin_keys,losses=trainer.fit_on_node_non_jit(policy, node, motor_env.tau, featurize_node, keys, opt_state)
plt.plot(losses)
plt.yscale('log')
# Out:
# 100%|██████████| 5000/5000 [00:44<00:00, 113.13it/s]

# %%
fin_policy_env,fin_opt_state2,fin_keys2,losses2=trainer.fit_non_jit(policy,motor_env,keys,opt_state)
plt.plot(losses2)
plt.yscale('log')
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
#  17%|█▋        | 872/5000 [00:40<03:11, 21.54it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 fin_policy_env,fin_opt_state2,fin_keys2,losses2=trainer.fit_non_jit(policy,motor_env,keys,opt_state)
#       2 plt.plot(losses2)
#       3 plt.yscale('log')
#
#     [... skipping hidden 1 frame]
#
# File ~/project/dpc_project/policy/policy_training.py:485, in DPCTrainer.fit_non_jit(self, policy, env, key, opt_state)
#     483 def fit_non_jit(self, policy, env, key, opt_state):
#     484     assert self.batch_size == key.shape[0]
# --> 485     final_policy, final_opt_state, final_key, losses = fit_on_env_non_jit(
#     486         policy=policy,
#     487         train_steps=self.train_steps,
#     488         env=env,
#     489         reset_env=self.reset_env,
#     490         data_gen_sin=self.data_gen_sin,
#     491         rng=key,
#     492         horizon_length=self.horizon_length,
#     493         featurize=self.featurize,
#     494         ref_loss_fun=self.ref_loss,
#     495         penalty_fun=self.constr_penalty,
#     496         optim=self.policy_optimizer,
#     497         init_opt_state=opt_state,
#     498         ref_loss_weight=self.ref_loss_weight,
#     499     )
#     501     return final_policy, final_opt_state, final_key, losses
#
# File ~/project/dpc_project/policy/policy_training.py:231, in fit_on_env_non_jit(policy, train_steps, env, reset_env, data_gen_sin, rng, horizon_length, featurize, ref_loss_fun, penalty_fun, optim, init_opt_state, ref_loss_weight)
#     227 for i in tqdm(range(train_steps)):
#     229     init_obs, ref_obs, key = data_generation(env, reset_env, data_gen_sin, key)
# --> 231     policy_state, opt_state, loss = make_step(
#     232         policy_state,
#     233         env,
#     234         init_obs,
#     235         ref_obs,
#     236         horizon_length,
#     237         featurize,
#     238         ref_loss_fun,
#     239         penalty_fun,
#     240         optim,
#     241         opt_state,
#     242         ref_loss_weight=ref_loss_weight,
#     243     )
#     245     losses.append(loss)
#     246 return policy_state, opt_state, key, losses
#
#     [... skipping hidden 3 frame]
#
# File ~/.conda/envs/venv_proj/lib/python3.11/site-packages/equinox/_module.py:910, in _unflatten_module(cls, aux, dynamic_field_values)
#     900     aux = _FlattenedData(
#     901         tuple(dynamic_field_names),
#     902         tuple(static_field_names),
#    (...)
#     905         tuple(wrapper_field_values),
#     906     )
#     907     return tuple(dynamic_field_values), aux
# --> 910 def _unflatten_module(cls: type["Module"], aux: _FlattenedData, dynamic_field_values):
#     911     # This doesn't go via `__init__`. A user may have done something nontrivial there,
#     912     # and the field values may be dummy values as used in various places throughout JAX.
#     913     # See also
#     914     # https://jax.readthedocs.io/en/latest/pytrees.html#custom-pytrees-and-initialization,
#     915     # which was (I believe) inspired by Equinox's approach here.
#     916     module = object.__new__(cls)
#     917     for name, value in zip(aux.dynamic_field_names, dynamic_field_values):
#
# KeyboardInterrupt:

# %%
from utils.evaluation import steps_eval

# %%
obs,obs_ref,acts=steps_eval(motor_env,reset,fin_policy_100,featurize,jax.random.PRNGKey(2),2000)

# %%
obs,obs_ref,acts=steps_eval(motor_env,reset,fin_policy_50,featurize,jax.random.PRNGKey(2),2000)

# %%
obs,obs_ref,acts=steps_eval(motor_env,reset,fin_policy_1,featurize,jax.random.PRNGKey(2),2000)

# %%
obs,obs_ref,acts=steps_eval(motor_env,reset,fin_policy_env,featurize,jax.random.PRNGKey(2),2000)

# %%
@eqx.filter_jit
def featurize_nint(obs,ref_obs, featurize_state=jnp.array([0,0])):
    feat_obs=jnp.concatenate([obs[0:2],ref_obs[0:2],ref_obs[0:2]-obs[0:2],featurize_state])#jnp.concatenate([obs[0:2],obs[6:8],ref_obs[0:2],ref_obs[0:2]-obs[0:2],featurize_state])
    #featurize_state=jnp.clip(featurize_state + ref_obs[0:2]-obs[0:2],min=-1,max=1) * (jnp.sign(0.01-jnp.sum((ref_obs[0:2]-obs[0:2])**2))*0.5+0.5)
    return feat_obs,featurize_state

# %%
data_batch_size=100
trainer_nint=DPCTrainer(
    batch_size=data_batch_size,
    train_steps=5000,
    horizon_length=25,
    reset_env=reset,
    data_gen_sin=node_dat_gen_sin,
    featurize=featurize_nint,
    policy_optimizer=optimizer,
    ref_loss=mse_loss,
    constr_penalty=penalty_loss,
    ref_loss_weight=1)
keys=jax.vmap(jax.random.PRNGKey)(np.random.randint(0, 2**31, size=(data_batch_size,)))
#key=jax.vmap(jax.random.PRNGKey)(jnp.linspace(0,1000,1001).astype(int))

# %%
jax_key = jax.random.PRNGKey(2)
node_struct=NeuralEulerODE([4,128,128,128,128,2],key=jax_key)
node = eqx.tree_deserialise_leaves("trained_models/Model_100k_1len_100b_step0_0001.eqx", node_struct)

# %%
fin_policy_1_nint,fin_opt_state,fin_keys,losses=trainer_nint.fit_on_node_non_jit(policy, node, motor_env.tau, featurize_node, keys, opt_state)
plt.plot(losses)
plt.yscale('log')
# Out:
#  61%|██████    | 3052/5000 [00:28<00:18, 108.07it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 fin_policy_1_nint,fin_opt_state,fin_keys,losses=trainer_nint.fit_on_node_non_jit(policy, node, motor_env.tau, featurize_node, keys, opt_state)
#       2 plt.plot(losses)
#       3 plt.yscale('log')
#
#     [... skipping hidden 1 frame]
#
# File ~/project/dpc_project/policy/policy_training.py:505, in DPCTrainer.fit_on_node_non_jit(self, policy, node, tau, featurize_node, key, opt_state)
#     503 def fit_on_node_non_jit(self, policy, node, tau, featurize_node, key, opt_state):
#     504     assert self.batch_size == key.shape[0]
# --> 505     final_policy, final_opt_state, final_key, losses = fit_on_node_non_jit(
#     506         policy=policy,
#     507         train_steps=self.train_steps,
#     508         node=node,
#     509         tau=tau,
#     510         featurize_node=featurize_node,
#     511         reset_env=self.reset_env,
#     512         data_gen_sin=self.data_gen_sin,
#     513         rng=key,
#     514         horizon_length=self.horizon_length,
#     515         featurize=self.featurize,
#     516         ref_loss_fun=self.ref_loss,
#     517         penalty_fun=self.constr_penalty,
#     518         optim=self.policy_optimizer,
#     519         init_opt_state=opt_state,
#     520         ref_loss_weight=self.ref_loss_weight,
#     521     )
#     522     return final_policy, final_opt_state, final_key, losses
#
# File ~/project/dpc_project/policy/policy_training.py:275, in fit_on_node_non_jit(policy, train_steps, node, tau, featurize_node, reset_env, data_gen_sin, rng, horizon_length, featurize, ref_loss_fun, penalty_fun, optim, init_opt_state, ref_loss_weight)
#     271 for i in tqdm(range(train_steps)):
#     273     init_obs, ref_obs, key = data_generation(node, reset_env, data_gen_sin, key)
# --> 275     policy_state, opt_state, loss = make_step_node(
#     276         policy_state,
#     277         node,
#     278         tau,
#     279         featurize_node,
#     280         init_obs,
#     281         ref_obs,
#     282         horizon_length,
#     283         featurize,
#     284         ref_loss_fun,
#     285         penalty_fun,
#     286         optim,
#     287         opt_state,
#     288         ref_loss_weight,
#     289     )
#     290     losses.append(loss)
#     291 return policy_state, opt_state, key, losses
#
#     [... skipping hidden 3 frame]
#
# File ~/.conda/envs/venv_proj/lib/python3.11/site-packages/equinox/_module.py:910, in _unflatten_module(cls, aux, dynamic_field_values)
#     900     aux = _FlattenedData(
#     901         tuple(dynamic_field_names),
#     902         tuple(static_field_names),
#    (...)
#     905         tuple(wrapper_field_values),
#     906     )
#     907     return tuple(dynamic_field_values), aux
# --> 910 def _unflatten_module(cls: type["Module"], aux: _FlattenedData, dynamic_field_values):
#     911     # This doesn't go via `__init__`. A user may have done something nontrivial there,
#     912     # and the field values may be dummy values as used in various places throughout JAX.
#     913     # See also
#     914     # https://jax.readthedocs.io/en/latest/pytrees.html#custom-pytrees-and-initialization,
#     915     # which was (I believe) inspired by Equinox's approach here.
#     916     module = object.__new__(cls)
#     917     for name, value in zip(aux.dynamic_field_names, dynamic_field_values):
#
# KeyboardInterrupt:

# %%
fin_policy_env_nint,fin_opt_state2,fin_keys2,losses2=trainer_nint.fit_non_jit(policy,motor_env,keys,opt_state)
plt.plot(losses2)
plt.yscale('log')
# Out:
# 100%|██████████| 5000/5000 [02:25<00:00, 34.38it/s]

# %%
obs,obs_ref,acts=steps_eval(motor_env,reset,fin_policy_1_nint,featurize_nint,jax.random.PRNGKey(2),2000)

# %%
obs,obs_ref,acts=steps_eval(motor_env,reset,fin_policy_env_nint,featurize_nint,jax.random.PRNGKey(2),2000)
