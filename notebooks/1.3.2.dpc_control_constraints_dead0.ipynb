# %%
import jax
import jax.nn as jnn
import jax.numpy as jnp
import numpy as np

import equinox as eqx
import diffrax
import optax
import matplotlib.pyplot as plt

# %%
import os
os.chdir("..")
from policy.policy_training import DPCTrainer
from exciting_environments.pmsm.pmsm_env import PMSM
from policy.networks import MLP,MLP2
# Out:
# 2024-11-08 12:53:03.870803: W external/xla/xla/service/gpu/nvptx_compiler.cc:760] The NVIDIA driver's CUDA version is 12.2 which is older than the ptxas CUDA version (12.6.77). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.

# %%
gpus = jax.devices()
jax.config.update("jax_default_device", gpus[0])

# %%
motor_env = PMSM(
    saturated=True,
    LUT_motor_name="BRUSA",
    batch_size=1,
    control_state=[],
    static_params = {
            "p": 3,
            "r_s": 15e-3,
            "l_d": 0.37e-3,
            "l_q": 1.2e-3,
            "psi_p": 65.6e-3,
            "deadtime": 0,
    })

# %%
@eqx.filter_jit
def reset_env(env,rng):
    obs, _ = env.reset(env.env_properties, rng)  #
    obs = obs.at[2].set((3*1500 / 60 * 2 * jnp.pi) / (2 * jnp.pi * 3 * 11000 / 60))
    return obs

# %%
@eqx.filter_jit
def motor_env_dat_gen_sin(env,reset_env, rng, traj_len):
    rng, subkey = jax.random.split(rng)
    ref_obs = reset_env(env,subkey) 
    rng, subkey = jax.random.split(rng)
    init_obs = reset_env(env,subkey)  
    return init_obs, ref_obs, rng

# %%
@eqx.filter_jit
def featurize(obs,ref_obs,feat_state=jnp.array([0,0])):
    feat_obs=jnp.concatenate([obs[0:2],obs[6:8],ref_obs[0:2],ref_obs[0:2]-obs[0:2]])
    return feat_obs, feat_state

# %%
jax_key = jax.random.PRNGKey(2)
policy=MLP([8,64,64,64,2], key=jax_key)
optimizer = optax.adam(5e-5)
opt_state = optimizer.init(policy)

# %%
@eqx.filter_jit
def mse_loss(feat_obs):
    loss=jnp.mean(jnp.sum((feat_obs[:,-2:])**2,axis=1))
    return loss

# %%
@eqx.filter_jit
def penalty_loss(feat_obs):
    i_d=feat_obs[:,0]*0.5-0.5
    i_q=feat_obs[:,1]
    penalties = jnp.sum(jax.nn.relu(i_d**2+i_q**2-1.05))
    return penalties

# %%
data_batch_size=100
trainer=DPCTrainer(
    batch_size=data_batch_size,
    train_steps=3000,
    horizon_length=50,
    reset_env=reset_env,
    data_gen_sin=motor_env_dat_gen_sin,
    featurize=featurize,
    policy_optimizer=optimizer,
    ref_loss=mse_loss,
    constr_penalty=penalty_loss,
    ref_loss_weight=1)
keys=jax.vmap(jax.random.PRNGKey)(np.random.randint(0, 2**31, size=(data_batch_size,)))
#key=jax.vmap(jax.random.PRNGKey)(jnp.linspace(0,1000,1001).astype(int))

# %%
fin_policy_1,fin_opt_state,fin_keys,losses=trainer.fit_non_jit(policy,motor_env,keys,opt_state)
plt.plot(losses)
plt.yscale('log')
# Out:
# 100%|██████████| 3000/3000 [02:47<00:00, 17.88it/s]

# %%
data_batch_size=100
trainer=DPCTrainer(
    batch_size=data_batch_size,
    train_steps=7000,
    horizon_length=50,
    reset_env=reset_env,
    data_gen_sin=motor_env_dat_gen_sin,
    featurize=featurize,
    policy_optimizer=optimizer,
    ref_loss=mse_loss,
    constr_penalty=penalty_loss,
    ref_loss_weight=0.95)
#keys=jax.vmap(jax.random.PRNGKey)(np.random.randint(0, 2**31, size=(data_batch_size,)))
#key=jax.vmap(jax.random.PRNGKey)(jnp.linspace(0,1000,1001).astype(int))

# %%
fin_policy_095,fin_opt_state,fin_keys,losses=trainer.fit_non_jit(policy,motor_env,keys,opt_state)
plt.plot(losses)
plt.yscale('log')
# Out:
# 100%|██████████| 7000/7000 [05:53<00:00, 19.80it/s]

# %%
@eqx.filter_jit
def penalty_loss(feat_obs):
    i_d=feat_obs[:,0]*0.5-0.5
    i_q=feat_obs[:,1]
    penalties = jnp.sum(jax.nn.relu(i_d**2+i_q**2-1))
    return penalties

# %%
data_batch_size=100
trainer=DPCTrainer(
    batch_size=data_batch_size,
    train_steps=3000,
    horizon_length=100,
    reset_env=reset_env,
    data_gen_sin=motor_env_dat_gen_sin,
    featurize=featurize,
    policy_optimizer=optimizer,
    ref_loss=mse_loss,
    constr_penalty=penalty_loss,
    ref_loss_weight=0.95)
#keys=jax.vmap(jax.random.PRNGKey)(np.random.randint(0, 2**31, size=(data_batch_size,)))
#key=jax.vmap(jax.random.PRNGKey)(jnp.linspace(0,1000,1001).astype(int))
fin_policy_095_hard,fin_opt_state,fin_keys,losses=trainer.fit_non_jit(policy,motor_env,keys,opt_state)
plt.plot(losses)
plt.yscale('log')
# Out:
#   3%|▎         | 149/5000 [00:14<07:59, 10.11it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 15
#       2 trainer=DPCTrainer(
#       3     batch_size=data_batch_size,
#       4     train_steps=5000,
#    (...)
#      11     constr_penalty=penalty_loss,
#      12     ref_loss_weight=0.95)
#      13 #keys=jax.vmap(jax.random.PRNGKey)(np.random.randint(0, 2**31, size=(data_batch_size,)))
#      14 #key=jax.vmap(jax.random.PRNGKey)(jnp.linspace(0,1000,1001).astype(int))
# ---> 15 fin_policy_095_hard,fin_opt_state,fin_keys,losses=trainer.fit_non_jit(policy,motor_env,keys,opt_state)
#      16 plt.plot(losses)
#      17 plt.yscale('log')
#
#     [... skipping hidden 1 frame]
#
# File ~/project/dpc_project/policy/policy_training.py:216, in DPCTrainer.fit_non_jit(self, policy, env, key, opt_state)
#     214 def fit_non_jit(self, policy, env, key, opt_state):
#     215     assert self.batch_size == key.shape[0]
# --> 216     final_policy, final_opt_state, final_key, losses = fit_non_jit(
#     217         policy=policy,
#     218         train_steps=self.train_steps,
#     219         env=env,
#     220         reset_env=self.reset_env,
#     221         data_gen_sin=self.data_gen_sin,
#     222         rng=key,
#     223         horizon_length=self.horizon_length,
#     224         featurize=self.featurize,
#     225         ref_loss_fun=self.ref_loss,
#     226         penalty_fun=self.constr_penalty,
#     227         optim=self.policy_optimizer,
#     228         init_opt_state=opt_state,
#     229         ref_loss_weight=self.ref_loss_weight,
#     230     )
#     232     return final_policy, final_opt_state, final_key, losses
#
# File ~/project/dpc_project/policy/policy_training.py:117, in fit_non_jit(policy, train_steps, env, reset_env, data_gen_sin, rng, horizon_length, featurize, ref_loss_fun, penalty_fun, optim, init_opt_state, ref_loss_weight)
#     113 for i in tqdm(range(train_steps)):
#     115     init_obs, ref_obs, key = data_generation(env, reset_env, data_gen_sin, key)
# --> 117     policy_state, opt_state, loss = make_step(
#     118         policy_state,
#     119         env,
#     120         init_obs,
#     121         ref_obs,
#     122         horizon_length,
#     123         featurize,
#     124         ref_loss_fun,
#     125         penalty_fun,
#     126         optim,
#     127         opt_state,
#     128         ref_loss_weight=ref_loss_weight,
#     129     )
#     130     losses.append(loss)
#     131 return policy_state, opt_state, key, losses
#
#     [... skipping hidden 3 frame]
#
# File ~/.conda/envs/venv_proj/lib/python3.11/site-packages/equinox/_module.py:910, in _unflatten_module(cls, aux, dynamic_field_values)
#     900     aux = _FlattenedData(
#     901         tuple(dynamic_field_names),
#     902         tuple(static_field_names),
#    (...)
#     905         tuple(wrapper_field_values),
#     906     )
#     907     return tuple(dynamic_field_values), aux
# --> 910 def _unflatten_module(cls: type["Module"], aux: _FlattenedData, dynamic_field_values):
#     911     # This doesn't go via `__init__`. A user may have done something nontrivial there,
#     912     # and the field values may be dummy values as used in various places throughout JAX.
#     913     # See also
#     914     # https://jax.readthedocs.io/en/latest/pytrees.html#custom-pytrees-and-initialization,
#     915     # which was (I believe) inspired by Equinox's approach here.
#     916     module = object.__new__(cls)
#     917     for name, value in zip(aux.dynamic_field_names, dynamic_field_values):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluate

# %%
from utils.evaluation import steps_eval

# %%
_,_,_=steps_eval(motor_env,reset_env,fin_policy_1,featurize,jax.random.PRNGKey(4),2000)

# %%
_,_,_=steps_eval(motor_env,reset_env,fin_policy_095,featurize,jax.random.PRNGKey(4),2000)

# %%
_,_,acts=steps_eval(motor_env,reset_env,fin_policy_095_hard,featurize,jax.random.PRNGKey(4),2000)
